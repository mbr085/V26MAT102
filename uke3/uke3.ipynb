# %% [markdown]
# # MAT 102 Brukerkurs i matematikk II
#
# Kursansvarlig: Morten Brun

# %% [markdown]
# ## Kursmål
#
# **Teori (Matematikk i Praksis)**:
# - Kapittel 10-12.
# - Linær algebra.
# - Differensial-ligninger (systemer).
# - Funksjoner av flere variable.
# - Hver av disse temaene er et helt kurs i seg selv (MAT121, MAT131, MAT212).
#
# **Numerikk i Python**:
# - Kompendiet.
# - Litt numeriske metoder (integrering og derivering).
# - Noe parameterestimering og statistikk.
# - Dette er også egne kurs (MAT260, MAT261, MAT265, osv.).
#
# Oppsummert: Vi skal lære litt basiskunnskap om (veldig) mye forskjellig
#
# ## Undervisningstilbud
#
# - Forelesning Mandager (10:15-12:00) og onsdager (12:15-14:00).
# - Fire kollokviegrupper. Marius Nevland og Peter Moritz von Schultzendorff er gruppeledere.
# - Du melder deg på gruppe gjennom emnet sin side på mittuib.

# %%
# Her importeres en quizz modul for jupyter.
# Hvis den ikke allerede er installert blir den installert.
try:
  from jupyterquiz import display_quiz
except:
  # !pip install jupyterquiz
  from jupyterquiz import display_quiz

# %%
# lenke til quizspørsmål
git_path="https://raw.githubusercontent.com/mbr085/V25MAT102/main/notebooks/uke3/"

# %%
display_quiz(git_path + "q1.json")
# Out:
# <div id="mNnDSWHqkljh" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #mNnDSWHqkljh {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %% [markdown]
# ## Obligatoriske innleveringer
#
# - Det blir tre obligatoriske oppgaver i løpet av kurset.
# - Krav for å kunne ta eksamen er å
#   + levere oppgavene i mittuib til fristen
#   + svare godt nok til at Marius og Peter mener at der er gjort et skikkelig forsøk på å løse oppgaven.
# - Hvis ikke oppgaven din blir godtatt selv om du har forsøkt deg på hele oppgaven kan du søke kursansvarlig skriftlig om å få levere en forbedret versjon av besvarelsen.
# - Det blir **ikke** gitt en fjerde oppgave til de som ikke har fått godkjent i løpet av semesteret.
# - Hvis du er forhindret fra å levere en oblig grunnet sykdom eller annet, så kontakt studieadministrasjonen (Kristine Lysnes) om dette.

# %%
display_quiz(git_path + "q2.json")
# Out:
# <div id="UBVkFDzVTiWL" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #UBVkFDzVTiWL {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %% [markdown]
# ## Eksamen
# - Dere må bestå alle tre obligatoriske øvelser for å ta eksamen.
# - Eksamen blir skriftlig/digital/Inspera, fire timer.
# - Jeg bruker eksamener som "retter seg selv":
# - Det kommer til å bli utstrakt bruk av flervalgs-oppgaver, og andre oppgaver
# hvor svaret er "rett eller galt".
# - Mange oppgaver gjennom semesteret blir av denne typen. Også deler av de obligatoriske oppgavene.
# - Det er flott å jobbe sammen. Siden du er alene til eksamen er det en god ide å gjøre noen oppgaver alene gjennom semesteret.
# - Det gis altså ingen poeng for "tenkte riktig men kom likevel frem til galt svar".

# %%
display_quiz(git_path + "q3.json")
# Out:
# <div id="bZXRUDhiVldT" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #bZXRUDhiVldT {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %% [markdown]
# ## Om tidsbruk
#
# - 10 studiepoeng (ECTS) er tilsvarende omtrent 250-300 timers arbeid.
#   - [https://en.wikipedia.org/wiki/European_Credit_Transfer_and_Accumulation_System](https://en.wikipedia.org/wiki/European_Credit_Transfer_and_Accumulation_System)
# - Det er 18 uker igjen til eksamen, så for de av dere som har hatt ferie
# frem til nå, bør dere altså forvente å bruke omtrent 14-17 timer per
# uke på dette faget frem til eksamen.
# - MAT102 er ett av de letteste matematikkfagene på UiB. Likevel strøk
# omtrent 20% i fjor. Derfor: Studer jevnt gjennom semesteret, så
# slipper du å se meg igjen her neste år

# %% [markdown]
# ### I fjor strøk 20 prosent av de som tok eksamen i MAT102.
# ![strykprosent](stryk.png "Tyve prosent stryk i MAT102")

# %% [markdown]
# ![karakterfordeling](karakterer.png "Karakterer")
