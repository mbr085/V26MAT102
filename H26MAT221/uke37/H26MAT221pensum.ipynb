# %% [markdown]
# # Pensumliste
# # MAT221 Diskret matematikk høst 2026

# %% [markdown]
# ### Ian Anderson: [A first course in discrete mathematics, Springer Verlag, 2002:](https://link.springer.com/book/10.1007/978-0-85729-315-2)
#
# * Seksjon 1.1 - 1.5
# * Seksjon 2.1 - 2.3 fram til (og ikke med) Example 2.7.
# * Seksjon 2.6 fra til og med figur 2.6.
# * Seksjon 3.1 - 3.5, 3.6 unntatt siste delen "Chords of a circle", 3.7
# * Seksjon 4.1, 4.5 untatt siste delen "An upper bound for the TSP", 4.6.
# * Seksjon 5.1 - 5.4.
# * Seksjon 6.1 - 6.3.
# * Seksjon 7.1 - 7.3.
# * Seksjon 8.1 unntatt Theorem 8.2, Example 8.3, Example 8.5 og Teorem 8.4.
# * Seksjon 8.2 unntatt siste delen "Another 1-factorisation of $K_{2n}$."
# * Seksjon 9.1 fram til (og ikke med) definisjon 9.3.

# %% [markdown]
# ##  Gunnar Fløystad: [Kompendium i tallteori, Bergen, 2011:](https://mitt.uib.no/courses/53823/files/6997737)
#
# * Seksjon 1.1 - 1.5.
# * Seksjon 2.1 - 2.5.
# * Seksjon 3.1 - 3.6.
# * Seksjon 4.1 - 4.3.
# * Seksjon 5.1 - 5.4.
