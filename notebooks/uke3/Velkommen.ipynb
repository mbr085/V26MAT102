# %% [markdown]
# # Velkommen til MAT 102.

# %% [markdown]
# Kursansvarlig: Morten Brun

# %% [markdown]
# ## Kursmål
#
# **Teori (Matematikk i Praksis)**:
# - Kapittel 10-12.
# - Linær algebra.
# - Differensial-ligninger (systemer).
# - Funksjoner av flere variable.
# - Hver av disse temaene er et helt kurs i seg selv (MAT121, MAT131, MAT212).
#
# **Numerikk i Python**:
# - Kompendiet.
# - Litt numeriske metoder (integrering og derivering).
# - Noe parameterestimering og statistikk.
# - Dette er også egne kurs (MAT260, MAT261, MAT265, osv.).
#
# Oppsummert: Vi skal lære litt basiskunnskap om (veldig) mye forskjellig
#
# ## Undervisningstilbud
#
# - Forelesning Mandager (12:15-14:00) og onsdager (14:15-16:00).
# - Kollokviegruppe.
# - Du melder deg på gruppe gjennom emnet sin side på mittuib.

# %% [markdown]
# ## Obligatoriske innleveringer
#
# - Det blir tre obligatoriske oppgaver i løpet av kurset.
# - Krav for å kunne ta eksamen er å
#   + levere oppgavene i mittuib til fristen
#   + svare godt nok til at vi mener at der er gjort et skikkelig forsøk på å løse oppgaven.
# - Hvis ikke oppgaven din blir godtatt selv om du har forsøkt deg på hele oppgaven kan du søke kursansvarlig skriftlig om å få levere en forbedret versjon av besvarelsen.
# - Det blir **ikke** gitt en fjerde oppgave til de som ikke har fått godkjent i løpet av semesteret.
# - Hvis du er forhindret fra å levere en oblig grunnet sykdom eller annet, så kontakt studieadministrasjonen (Kristine Lysnes) om dette.

# %% [markdown]
# ## Om tidsbruk
#
# - 10 studiepoeng (ECTS) er tilsvarende omtrent 250-300 timers arbeid.
#   - [https://en.wikipedia.org/wiki/European_Credit_Transfer_and_Accumulation_System](https://en.wikipedia.org/wiki/European_Credit_Transfer_and_Accumulation_System)
# - Det er 18 uker igjen til eksamen, så dere kan forvente trenge å bruke omtrent 14-17 timer per
# uke på dette faget frem til eksamen.
# - MAT102 er ett av de letteste matematikkfagene på UiB. Likevel strøk
# mange i fjor. Derfor: Studer jevnt gjennom semesteret, så
# slipper du å se meg igjen her neste år

# %% [markdown]
# ## Karakterfordeling i fjor
#
# | Karakter     | Antall kandidater      |
# | ------------- | ------------- |
# | A | 3 |
# | B | 7 |
# | C | 16 |
# | D | 11 |
# | E | 11 |
# | F | 7 |
#
# **Stryk**: 13 prosent av de som møtte til eksamen.

# %% [markdown]
# ## Introduksjon til Python
#
# I denne uke vil jeg vise hvordan vi kommer til å bruke python i dette kurset.
#
# * [Enkle beregninger med python.](K1_enkle_beregninger.ipynb)
# * [Plotte grafer.](K1_plotte_grafer.ipynb)
# * [Dataanalyse.](K1_dataanalyse.ipynb)
