# %% [markdown]
# # Uke 13: Parameterestimering og lineær regresjon
#
# - [Kjerneregelen igjen](../uke12/kjerneregelen.ipynb)
# - [Gradient descent](../uke11/gradient_descent.ipynb)
# - [Lineær regresjon](../uke11/lineærRegresjon.ipynb)
# - [Regresjon av temperaturer](Regresjon_temperaturer.ipynb)
# - [Regresjon med variasjoner](Variasjoner_temperatur.ipynb)
