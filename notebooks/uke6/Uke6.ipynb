# %% [markdown]
# # Uke 6: Differensialligniger

# %% [markdown]
# Denne uken ser vi på differensialligninger, og hvordan vi kan lage python til å løse dem.
#
# - [Differensialligninger og retningsfelt](Differensialligninger.ipynb)
# - [Eulers metode](Eulers_Metode.ipynb)
# - [Systemer av differensialligninger](Systemer_av_diffligninger.ipynb)
#     - [Tømming av vanntanker](Tømming_av_vanntanker.ipynb)
#     - [Svingninger](Svingninger.ipynb)
#     - [Lotka Voltera](LotkaVoltera.ipynb)
