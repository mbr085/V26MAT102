# %% [markdown]
# # Matrisereduksjon

# %% [markdown]
# ## Oppgave
#
# Løs ligningssystemet
# $$
# \begin{array}{cccccc}
#   x_1  & -2x_2  &    &   & = 0\\
#   x_1  & -2x_2  &    &  +x_4 & = 0\\
#   0  &  2x_2  & -2x_3  &  +3x_4 & = 0
# \end{array}
# $$
