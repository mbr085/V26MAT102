# %% [markdown]
# # Uke 17
#
# ## Repetisjon
#
# Vi vil snakke om
#
# - [Gradient](gradient.ipynb)
# - [Eulers metode](eulersmetode.ipynb)
# - [Matrisereduksjon](matrisereduksjon.ipynb)
# - [Eigenverdier](eigenverdier.ipynb)
# - [System av lineære differensialligninger](difflign.ipynb)
# - [paret t-test](paretttest.ipynb)
# - [To utvalgs t-test](toutvalgttest.ipynb)
