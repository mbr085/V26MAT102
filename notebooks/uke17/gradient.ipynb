# %% [markdown]
# # Gradient

# %% [markdown]
# ## Oppgave
#
# La
# $$F \colon \mathbb{R}^2 \to \mathbb{R}$$
# være gitt ved
# $$F(\begin{bmatrix} x\\y  \end{bmatrix} = x^2 + y^2.$$
#
# Beregn gradienten til $F$.
