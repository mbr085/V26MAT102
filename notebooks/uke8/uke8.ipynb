# %% [markdown]
# # Uke 8: Inverse matriser, egenverdier og egenvektorer

# %% [markdown]
# Vi fortsetter med matriser og lineær algebra.
#
# - [Inverse matriser](107inverseMatriser.ipynb)
# - [Egenverdier og egenvektorer](108egenverdier.ipynb)
# - [Matrisedynamikk](109Matrisedynamikk.ipynb)
