# %% [markdown]
# # Uke 7: Matriser og vektorer

# %% [markdown]
# Denne uken begynner vi å jobbe med matriser og vektorer.
#
# - [Matriser og vektorer](101matriser_og_vektorer.ipynb)
# - [Avstand og plan](102avstandplan.ipynb)
# - [Lineære ligningssystemer](103linearesystem.ipynb)
# - [Gauss Jordan eliminasjon](104gaussjordan.ipynb)
# - [Produkt av matriser](105matriseprodukt.ipynb)
