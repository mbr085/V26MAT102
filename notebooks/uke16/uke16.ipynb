# %% [markdown]
# # Uke 16: Hypotesetest
#
# - [Hypotesetesting](../uke15/hypotesetest.ipynb)
# - [Paret t-test](../uke15/parettemperaturer.ipynb)
# - [To utvalgs t-test](../uke15/to_utvalgs_t_test.ipynb)
# - [Test av stigningstall for regresjonslinje](../uke15/testhelding.ipynb)
