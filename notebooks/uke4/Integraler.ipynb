# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# def f(x):
#     return x**4 - 2*x -.5
#
# n = 4
# N = 400
# a = -1.5
# b = 1.5

# %%
def f(x):
    return 2*np.sin(x) + np.cos(x)

n = 4
N = 400
a = -2
b = 2

# %%
# n = 6
# N = 400
# a = -1.5
# b = 1.5
fig, ax = plt.subplots(figsize=(6, 3))
x = np.linspace(a, b, N)
xx = x #np.repeat(np.linspace(a, b, n + 1), 2)
ax.plot(x, f(x), color='black', linewidth=2)
ax.plot(x, np.zeros_like(x), color='black', linewidth=1)
# plt.plot(xx[1:-1], f(xx[2:]))
ax.fill_between(xx[1:-1], f(xx[2:]), where = (f(xx[2:]) >0), color='blue', alpha=0.4)
ax.fill_between(xx[1:-1], f(xx[2:]), where = (f(xx[2:]) <0), color='red', alpha=0.4)
# for xi in xx[::2]:
#     ax.plot([xi, xi], [0, f(xi)], color='black', linestyle='dotted')
#     ax.plot(xi, f(xi), 'ko')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.set_title(r'Integralet $\int_{-2}^{2} (2 \sin(x) + \cos(x))dx$')
#ax.legend()
ax.grid(True)
fig.savefig('mixedIntegral.png')

# %%
# n = 6
# N = 400
# a = -1.5
# b = 1.5
fig, ax = plt.subplots(figsize=(6, 3))
x = np.linspace(a, b, N)
xx = x #np.repeat(np.linspace(a, b, n + 1), 2)
ax.plot(x, f(x), color='black', linewidth=2)
ax.plot(x, np.zeros_like(x), color='black', linewidth=1)
# plt.plot(xx[1:-1], f(xx[2:]))
ax.fill_between(xx[1:-1], f(xx[2:]), where = (f(xx[2:]) >0), color='blue', alpha=0.4)
ax.fill_between(xx[1:-1], f(xx[2:]), where = (f(xx[2:]) <0), color='red', alpha=0.4)
xx = np.repeat(np.linspace(a, b, n + 1), 2)
for xi in xx[::2]:
    # ax.plot([xi, xi], [0, f(xi)], color='black', linestyle='dotted')
    ax.plot(xi, f(xi), 'ko')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')

#ax.legend()
ax.grid(True)
fig.savefig('mixedIntegral_med_punkter.png')

# %%
# n = 6
# N = 400
# a = -1.5
# b = 1.5
fig, ax = plt.subplots(figsize=(6, 3))
x = np.linspace(a, b, N)
xx = np.repeat(np.linspace(a, b, n + 1), 2)
yy = f(xx[:-2])
ax.plot(x, f(x), color='black', linewidth=2)
ax.plot(x, np.zeros_like(x), color='black', linewidth=1)
# plt.plot(xx[1:-1], f(xx[2:]))
ax.fill_between(xx[1:-1], yy, where = (yy >0), color='blue', alpha=0.4)
ax.fill_between(xx[1:-1], yy, where = (yy <0), color='red', alpha=0.4)
for xi in xx[::2]:
    ax.plot([xi, xi], [0, f(xi)], color='black', linestyle='dotted')
    ax.plot(xi, f(xi), 'ko')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.set_title(r'Konstant med verdien i venstre endepunkt.')
#ax.legend()
ax.grid(True)
fig.savefig('mixedIntegralL.png')

# %%
# n = 6
# N = 400
# a = -1.5
# b = 1.5
fig, ax = plt.subplots(figsize=(6, 3))
x = np.linspace(a, b, N)
xx = np.repeat(np.linspace(a, b, n + 1), 2)
yy = f(xx[2:])
ax.plot(x, f(x), color='black', linewidth=2)
ax.plot(x, np.zeros_like(x), color='black', linewidth=1)
# plt.plot(xx[1:-1], f(xx[2:]))
ax.fill_between(xx[1:-1], yy, where = (yy >0), color='blue', alpha=0.4)
ax.fill_between(xx[1:-1], yy, where = (yy <0), color='red', alpha=0.4)
for xi in xx[::2]:
    ax.plot([xi, xi], [0, f(xi)], color='black', linestyle='dotted')
    ax.plot(xi, f(xi), 'ko')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.set_title(r'Konstant med verdien i høyre endepunkt.')
#ax.legend()
ax.grid(True)
fig.savefig('mixedIntegralR.png')

# %%
xx
# Out:
# array([-2., -2., -1., -1.,  0.,  0.,  1.,  1.,  2.,  2.])

# %%
f(xx[::2])
# Out:
# array([-2.23474169, -1.14263966,  1.        ,  2.22324428,  1.40244802])

# %%
# n = 6
# N = 400
# a = -1.5
# b = 1.5
fig, ax = plt.subplots(figsize=(6, 3))
x = np.linspace(a, b, N)
xx = np.repeat(np.linspace(a, b, n + 1), 2)
yy = np.minimum(f(xx[2:]), f(xx[:-2]))
ax.plot(x, f(x), color='black', linewidth=2)
ax.plot(x, np.zeros_like(x), color='black', linewidth=1)
# plt.plot(xx[1:-1], f(xx[2:]))
ax.fill_between(xx[1:-1], yy, where = (yy >0), color='blue', alpha=0.4)
ax.fill_between(xx[1:-1], yy, where = (yy <0), color='red', alpha=0.4)
for xi in xx[::2]:
    ax.plot([xi, xi], [0, f(xi)], color='black', linestyle='dotted')
    ax.plot(xi, f(xi), 'ko')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
#ax.legend()
ax.grid(True)
fig.savefig('mixedRiemannLower.png')

# %%
# n = 6
# N = 400
# a = -1.5
# b = 1.5
fig, ax = plt.subplots(figsize=(6, 3))
x = np.linspace(a, b, N)
xx = np.repeat(np.linspace(a, b, n + 1), 2)
ax.plot(x, f(x), color='black', linewidth=2)
ax.plot(x, np.zeros_like(x), color='black', linewidth=1)
# plt.plot(xx[1:-1], f(xx[2:]))
ax.fill_between(xx[1:-1], f(xx[2:]), where = (f(xx[2:]) >0), color='blue', alpha=0.4)
ax.fill_between(xx[1:-1], f(xx[2:]), where = (f(xx[2:]) <0), color='red', alpha=0.4)
for xi in xx[::2]:
    ax.plot([xi, xi], [0, f(xi)], color='black', linestyle='dotted')
    ax.plot(xi, f(xi), 'ko')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
#ax.legend()
ax.grid(True)
fig.savefig('mixedRiemannR.png')

# %%
# n = 6
# N = 400

fig, ax = plt.subplots(figsize=(2, 1))
x = np.linspace(a, b, N)
xx = np.repeat(np.linspace(a, b, n + 1), 2)
ax.plot(x, f(x), color='black', linewidth=2)
ax.plot(x, np.zeros_like(x), color='black', linewidth=1)
# plt.plot(xx[1:-1], f(xx[2:]))
ax.fill_between(xx[1:-1], f(xx[:-2]), where = (f(xx[:-2]) >0), color='blue', alpha=0.4)
ax.fill_between(xx[1:-1], f(xx[:-2]), where = (f(xx[:-2]) <0), color='red', alpha=0.4)
for xi in xx[::2]:
    ax.plot([xi, xi], [0, f(xi)], color='black', linestyle='dotted')
    ax.plot(xi, f(xi), 'ko')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
#ax.legend()
ax.grid(True)
fig.savefig('mixedRiemannL.png')

# %%
# n = 6
# N = 400

fig, ax = plt.subplots(figsize=(2, 1))
x = np.linspace(a, b, N)
xx = np.linspace(a, b, n + 1)
ax.plot(x, f(x), color='black', linewidth=2)
ax.plot(x, np.zeros_like(x), color='black', linewidth=1)
ax.plot(xx, f(xx), color='black', linewidth=1)

left = x[0]
xxx = [left]
yyy = [f(left)]
for left, right in zip(xx[:-1], xx[1:]):
    aa, bb = f(left), f(right)
    if aa * bb >= 0:
        xxx.append(right)
        yyy.append(f(right))
    else:
        z = left + aa * (right - left) / (aa - bb)
        xxx.append(z)
        yyy.append(0)
        xxx.append(right)
        yyy.append(f(right))
xxx = np.array(xxx)
yyy = np.array(yyy)
ax.fill_between(xxx, yyy, where = (yyy >=0), color='blue', alpha=0.4)
ax.fill_between(xxx, yyy, where = (yyy <=0), color='red', alpha=0.4)
# ax.fill_between(xx[1:-1], f(xx[:-2]), where = (f(xx[:-2]) <0), color='red', alpha=0.4)
for xi in xx:
    ax.plot([xi, xi], [0, f(xi)], color='black', linestyle='dotted')
    ax.plot(xi, f(xi), 'ko')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
#ax.legend()
ax.grid(True)
fig.savefig('mixedTrapez.png')

# %%
fig, ax = plt.subplots(figsize=(2, 1))
a = -1
b = 1
x = np.linspace(a, b, N)
xx = np.linspace(a, b, n + 1)
ax.plot(x, f(x), color='black', linewidth=2)
ax.plot(x, np.zeros_like(x), color='black', linewidth=1)
#ax.plot(xx, f(xx), color='black', linewidth=1)

# %%
yyy
# Out:
# array([ 4.75,  2.5 ,  0.75,  0.  , -0.5 , -1.25, -1.5 , -1.25])

# %%
xxx
# Out:
# array([-1.5, -1. , -0.5, -0.2,  0. ,  0.5,  1. ,  1.5])

# %%
f(xx[:-1]) * f(xx[1:])
# Out:
# array([11.875,  1.875, -0.375,  0.625,  1.875,  1.875])

# %%
xx[2:][::2]
# Out:
# array([-0.5,  0.5,  1.5])

# %%
xx[:-1][::2]
# Out:
# array([-1.5, -0.5,  0.5])

# %%
xx
# Out:
# array([-1.5, -1. , -0.5,  0. ,  0.5,  1. ,  1.5])

# %%
xx[::2]
# Out:
# array([-1.5, -0.5,  0.5,  1.5])

# %%
n = 6
N = 400

fig, ax = plt.subplots(figsize=(2, 1))
x = np.linspace(a, b, N)
xx = np.repeat(np.linspace(a, b, n + 1), 2)
ax.plot(x, f(x), color='black', linewidth=2)
ax.plot(x, np.zeros_like(x), color='black', linewidth=1)
# plt.plot(xx[1:-1], f(xx[2:]))
ax.fill_between(xx[1:][::2], f(xx[1:][::2]), where = (f(xx[1:][::2]) + f(xx[:-1][::2]) <= 0), color='blue', alpha=0.4)
#ax.fill_between(xx[1:-1], f(xx[:-2]), where = (f(xx[:-2]) <0), color='red', alpha=0.4)
for xi in xx[::2]:
    ax.plot([xi, xi], [0, f(xi)], color='black', linestyle='dotted')
    ax.plot(xi, f(xi), 'ko')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
#ax.legend()
ax.grid(True)

# %%
n = 6
N = 400

fig, ax = plt.subplots(figsize=(2, 1))
x = np.linspace(a, b, N)
xx = np.linspace(a, b, n + 1)
ax.plot(x, f(x), color='black', linewidth=2)
ax.plot(x, np.zeros_like(x), color='black', linewidth=1)
# plt.plot(xx[1:-1], f(xx[2:]))
w1 = np.ones_like(xx, dtype=bool)
w2 = np.ones_like(xx, dtype=bool)
w1[1:] = f(xx[1:]) + f(xx[:-1]) <= 0
#w1[:-1] = np.logical_or(w1[1:], w1[:-1])
w2[1:] = f(xx[1:]) + f(xx[:-1]) >= 0
w2[:-1] = np.logical_or(w2[1:], w2[:-1])
#ax.fill_between(xx, f(xx), where = (f(xx) >0), color='blue', alpha=0.4)
ax.fill_between(xx, f(xx), where = w1, color='red', alpha=0.4)
for xi in xx:
    ax.plot([xi, xi], [0, f(xi)], color='black', linestyle='dotted')
    ax.plot(xi, f(xi), 'ko')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
#ax.legend()
ax.grid(True)

# %%
f(xx)
# Out:
# array([ 4.75,  2.5 ,  0.75, -0.5 , -1.25, -1.5 , -1.25])

# %%
w1
# Out:
# array([ True, False, False, False,  True,  True,  True])

# %%
w1
# Out:
# array([ True, False, False, False,  True,  True,  True])

# %%
w2
# Out:
# array([ True,  True,  True,  True, False, False, False])

# %%
f(xx[:-1]) + f(xx[1:])
# Out:
# array([ 7.25,  3.25,  0.25, -1.75, -2.75, -2.75])

# %%
n = 6
N = 400

x = np.linspace(a, b, N)
xx = np.repeat(np.linspace(a, b, n + 1), 2)
plt.plot(x, f(x), color='black', linewidth=2)
# plt.plot(xx[1:-1], f(xx[2:]))
plt.fill_between(xx[1:-1], f(xx[:-2]), where = (f(xx[2:]) >0), color='blue', alpha=0.4)
plt.fill_between(xx[1:-1], f(xx[:-2]), where = (f(xx[2:]) <0), color='red', alpha=0.4)
for xi in xx[::2]:
    plt.plot([xi, xi], [0, f(xi)], color='black', linestyle='dotted')
    plt.plot(xi, f(xi), 'ko')

# %%
plt.plot(xx, f(xx))

# %%
xxx = np.repeat(xx, 2)

# %%
f(xxx)
# Out:
# array([ 4.75,  4.75,  4.75,  4.75,  2.5 ,  2.5 ,  2.5 ,  2.5 ,  0.75,
#         0.75,  0.75,  0.75, -0.5 , -0.5 , -0.5 , -0.5 , -1.25, -1.25,
#        -1.25, -1.25, -1.5 , -1.5 , -1.5 , -1.5 , -1.25, -1.25, -1.25,
#        -1.25])

# %%
plt.plot(xxx[1:-1], f(xxx)[:-2])
plt.plot(xx, f(xx))

# %%
yy = np.linspace(x[0], x[-1], 8)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def f(x):
    return x**3 - 2*x -.5

# Interval [a, b] and number of rectangles
a, b = -1.5, 1.5
n = 6
x_left = np.linspace(a, b, n + 1)[:-1]  # left endpoints
dx = x_left[1] - x_left[0]
y_left = f(x_left)

# Plot setup
x = np.linspace(a, b, 400)
y = f(x)

fig, ax = plt.subplots(figsize=(2, 1))
ax.plot(x, y, 'r', linewidth=2) #, label='f(x)=x3−2x+2')
ax.bar(x_left, y_left, width=dx, align='edge', alpha=0.4, facecolor='blue', edgecolor='black') #, label='Left Riemann Sum')
ax.bar(x_left, y_left, width=dx, align='edge', alpha=0.4, facecolor='blue', edgecolor='black') #, label='Left Riemann Sum')

# Annotations
for xi, yi in zip(x_left, y_left):
    ax.plot([xi, xi], [0, yi], color='black', linestyle='dotted')
    ax.plot(xi, yi, 'ko')

#ax.set_title('Left Riemann Sum')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
#ax.legend()
ax.grid(True)
plt.savefig('venstreR.png')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
#def f(x):
#    return x**3 - 2*x + 1.5

# Interval [a, b] and number of rectangles
a, b = -1.5, 1.5
n = 6
x_left = np.linspace(a, b, n + 1)[1:]  # left endpoints
dx = x_left[1] - x_left[0]
y_left = f(x_left)

# Plot setup
x = np.linspace(a, b, 400)
y = f(x)

fig, ax = plt.subplots(figsize=(2, 1))
ax.plot(x, y, 'r', linewidth=2, label='f(x)=x3−2x+2')
ax.bar(x_left - dx, y_left, width=dx, align='edge', alpha=0.4, facecolor='blue', edgecolor='black') #, label='Left Riemann Sum')

# Annotations
for xi, yi in zip(x_left, y_left):
    ax.plot([xi, xi], [0, yi], color='black', linestyle='dotted')
    ax.plot(xi, yi, 'ko')

# ax.set_title('Left Riemann Sum')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
#ax.legend()
ax.grid(True)
plt.savefig('høyreR.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
#def f(x):
#    return x**3 - 2*x + 1.5

# Interval [a, b] and number of rectangles
a, b = -1.5, 1.5
n = 6
xx = np.linspace(a, b, n + 1)  # left endpoints
dx = x_left[1] - x_left[0]
y_left = f(x_left)

# Plot setup
x = np.linspace(a, b, 400)
y = f(x)

fig, ax = plt.subplots(figsize=(2, 1))
ax.plot(x, y, 'r', linewidth=2, label='f(x)=x3−2x+2')
plt.fill_between(xx, f(xx), color='blue', alpha=0.4)
#ax.bar(x_left - dx, y_left, width=dx, align='edge', alpha=0.4, edgecolor='black') #, label='Left Riemann Sum')

# Annotations
for xi, yi in zip(x_left, y_left):
    ax.plot([xi, xi], [0, yi], color='black', linestyle='dotted')
    ax.plot(xi, yi, 'ko')

# ax.set_title('Left Riemann Sum')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
#ax.legend()
plt.savefig('trapes.png')
ax.grid(True)

plt.show()
