# %% [markdown]
# # MAT 102 uke 5.

# %% [markdown]
# ## Numeriske metoder
#
# I denne uke vil jeg gå gjennom noen metoder til å gjøre kalkulus ut ifra lister av tall.
#
# * [Newtons metode til å finne nullpunkter](K2_Newtons_metode.ipynb)
# * [Numerisk derivasjon](numerisk_derivasjon.ipynb)
# * [Numerisk integrasjon ](Integrasjon.ipynb)
# * [Trapes sum](trapes.ipynb)
